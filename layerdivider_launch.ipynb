# %% [markdown]
# <a href="https://colab.research.google.com/github/azunyamunamu/skills-introduction-to-github/blob/main/layerdivider_launch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Please set runtime to GPU

# %%
# !git clone https://github.com/mattyamonaca/layerdivider.git
# Out:
# fatal: destination path 'layerdivider' already exists and is not an empty directory.

# %%
# %cd layerdivider
# Out:
# /content/layerdivider

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached opencv_python-4.7.0.68-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# ...
#   Using cached pandas-1.5.3.tar.gz (5.2 MB)
#   Installing build dependencies ... done
# ERROR: Operation cancelled by user
#   Getting requirements to build wheel ...

# %%
# !pip -q install -U pip setuptools wheel jedi
# !pip -q install -r requirements-colab.txt

# （重要）ランタイム再起動
import os; os.kill(os.getpid(), 9)
# Out:
#   Preparing metadata (setup.py) ... done
# ERROR: Could not find a version that satisfies the requirement onnxruntime-gpu==1.17.3 (from versions: 1.17.0, 1.17.1, 1.18.0, 1.18.1, 1.19.0, 1.19.2, 1.20.0, 1.20.1, 1.20.2, 1.21.0, 1.21.1, 1.22.0)
# ERROR: No matching distribution found for onnxruntime-gpu==1.17.3

# %%
# %%bash
# cat > requirements-colab.txt <<'REQ'
# opencv-python==4.10.0.84
# pandas==2.2.2
# gradio==3.16.2
# scikit-learn==1.6.1
# scikit-image==0.24.0
# Pillow==10.4.0
# tqdm==4.66.5
# pytoshop==1.2.1
# psd-tools==1.9.32
# gradio_client==0.16.4
# onnx==1.16.2
# onnxruntime-gpu==1.17.3
# huggingface_hub==0.24.6
# segment-anything
# requests>=2.32.3
# einops>=0.7.0
# # numpy は Colab 既定を使用（固定しない）
# REQ

# %%
# !python demo.py share
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py", line 787, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py", line 464, in _make_request
#     self._validate_conn(conn)
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py", line 1093, in _validate_conn
#     conn.connect()
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connection.py", line 753, in connect
#     self.sock = sock = self._new_conn()
#                        ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/connection.py", line 198, in _new_conn
#     sock = connection.create_connection(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/urllib3/util/connection.py", line 73, in create_connection
#     sock.connect(sa)
# KeyboardInterrupt
#
# ...

# %%
# !python -V
# Out:
# Python 3.12.11

# %%
# 依存解決を安定化
# !pip -q install -U pip setuptools wheel

# ColabのPy3.10/3.11/3.12のどれでもビルド不要で入る組み合わせ
# !pip -q install "opencv-python==4.10.0.84" "pandas==2.2.2" "gradio==3.16.2" "scikit-learn==1.5.2"

# 動作確認（バージョン表示）
import cv2, pandas as pd, sklearn, gradio
print("opencv:", cv2.__version__)
print("pandas:", pd.__version__)
print("sklearn:", sklearn.__version__)
print("gradio:", gradio.__version__)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 67.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# opencv: 4.10.0
# pandas: 2.2.2
# sklearn: 1.5.2
# gradio: 3.16.2
# /usr/local/lib/python3.12/dist-packages/gradio/routes.py:23: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
# IPythonの依存を満たす
# !pip -q install -U jedi

# 使わないなら競合元のパッケージを外す
# !pip -q uninstall -y umap-learn

# ランタイム再起動（必須）
import os; os.kill(os.getpid(), 9)
